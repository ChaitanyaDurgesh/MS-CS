# %%
pip install autogen
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flaml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flaml[automl]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade paramiko cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autogen import ConversableAgent

# %%
llm_config = [
    {
        "model": "gpt-4o-mini",
        "api_key": "sk-j7HR-Hx3ZClCrxcJwGiOpfafshi_jNRy9U9nNySFHnT3BlbkFJx5KePtp8U7Uc-UXZB9DK6kL7Wos0fBO97Gc5Y0JKIA",
        "temperature": 0.5,
        "max_tokens": 2048
    }
]

# %%
from autogen import ConversableAgent

# Customer Proxy Agent (User Interface)
customer_proxy_agent = ConversableAgent(
    name="customer_proxy",
    system_message=(
        """You are representing the user interface for a budgeting application, responsible for conveying comprehensive requirements for building an all-encompassing budgeting system. 
           The system should enable users to input income sources, log expenses, track savings, and generate financial reports. Additionally, the app should integrate with external financial services for real-time data and provide notifications on budget limits.
           
           Your goal is to create a unified, user-friendly system that supports every aspect of personal finance management, ensuring users can monitor their spending and plan their budgets effectively."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The representative of the budgeting app user interface"
)

# Project Manager Agent (Managing Cross-functional Coordination)
project_manager_agent = ConversableAgent(
    name="project_manager",
    system_message=(
        """You are a project manager overseeing the development of a self-budgeting application overseeing the transition from Waterfall to Scrum. Your role involves coordinating cross-functional teams (requirement engineers, software developers, and system engineers) to ensure the app is delivered on time, within scope, and aligned with the users' needs for personal finance management.

        Calculate the {effort} needed for the project plan using the following steps:

        Step 1: Determine the {work}, which is the total number of tasks required to build the budgeting app.
        Step 2: Define the productivity rate as {3 tasks completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        You are responsible for ensuring the system supports core features like income tracking, expense monitoring, savings goals, and real-time reporting."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The project manager responsible for the budgeting app"
)

# Requirement Engineer Agent (Gathering Requirements)
requirement_engineer_agent = ConversableAgent(
    name="requirement_engineer_agent",
    system_message=(
        """You are a requirement engineer gathering key use cases for the budgeting application. Your role involves identifying needs for tracking multiple income streams, categorizing expenses, setting savings goals, and generating financial reports. 

        Calculate the {effort} to document the requirements as follows:

        Step 1: Determine the {work}, which is the estimated total number of requirements for all use cases.
        Step 2: Set the productivity rate to {5 requirements completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that each requirement is actionable and supports the core features of the budgeting app."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer gathering requirements for the budgeting app"
)

# System Engineer Agent (Designing System Architecture)
system_engineer_agent = ConversableAgent(
    name="system_engineer_agent",
    system_message=(
        """You are a system engineer responsible for designing the architecture of the budgeting application. Your task includes designing the database schema for tracking income, expenses, and savings goals, and planning the integration with external financial services.
        
        Calculate the {effort} for the design document as follows:

        Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        Step 2: Set the productivity rate to {2 pages completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that the design supports efficient financial tracking, data security, and scalability."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for designing the system architecture for the budgeting app"
)

# Software Engineer Agent (Developing Source Code)
software_engineer_agent = ConversableAgent(
    name="software_engineer_agent",
    system_message=(
        """You are a software engineer in the Scrum team who is tasked with developing the budgeting app. Your role involves writing the frontend and backend code, implementing the user dashboard, and integrating financial APIs for real-time data.

        Calculate the {effort} to write the source code as follows:

        Step 1: Determine the {work}, which is the total number of lines of code (SLOC) required for the app.
        Step 2: Set the productivity rate to {50 SLOC completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure the codebase is secure, scalable, and efficient for managing personal finances."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for writing the source code for the budgeting app"
)


# Product Owner Agent (Managing the product)
product_owner_agent = ConversableAgent(
    name="product_owner_agent",
    system_message=(
        """You are the product owner responsible for managing the product backlog and setting priorities for the self-budgeting application. You work closely with stakeholders to understand their needs and translate them into clear, actionable user stories.    
        
        ##Calculate the {effort} for the design document as follows:

        ##Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        ##Step 2: Set the productivity rate to {5 pages completed per day}.
        ##Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that the team is always working on the most valuable features that align with the product vision and market demands."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The product owner responsible for managing the product backlog and setting priorities for the self-budgeting application"
)


# Scrum Master Agent (Process adherence)
scrum_master_agent = ConversableAgent(
    name="scrum_master_agent",
    system_message=(
        """You are the Scrum Master facilitating Scrum events and ensuring process adherence for the self-budgeting application project. You coach the team on Agile principles, remove obstacles that hinder progress, and foster a collaborative environment. Your role involves optimizing team performance and helping maintain focus on delivering high-quality increments of the product in each sprint.
        
        ##Calculate the {effort} for the design document as follows:

        ##Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        ##Step 2: Set the productivity rate to {4 pages completed per day}.
        ##Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that the team is always working on the most valuable features that align with the product vision and market demands."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The Scrum Master facilitating Scrum events and ensuring process adherence for the self-budgeting application project"
)


# Quality Assurance Engineer Agent (Process adherence)
qa_engineer_agent = ConversableAgent(
    name="qa_engineer_agent",
    system_message=(
        """You are a QA engineer in the Scrum team responsible for testing the self-budgeting application. Your role involves creating and executing test plans, identifying and reporting bugs. You work closely with developers to implement automated testing strategies and participate in sprint reviews to provide quality assurance insights.
        
        ##Calculate the {effort} for the design document as follows:

        ##Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        ##Step 2: Set the productivity rate to {3 pages completed per day}.
        ##Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that the application meets quality standards before release."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="A QA engineer in the Scrum team responsible for testing the self-budgeting application"
)


# UI/UX designer Engineer Agent (Process adherence)
ui_ux_designer_agent = ConversableAgent(
    name="ui_ux_designer_agent",
    system_message=(
        """You are a UI/UX designer in the Scrum team working on the self-budgeting application interface. Your focus is on creating an intuitive, visually appealing, and user-friendly design that enhances the overall user experience. You conduct user research, create wireframes and prototypes, and collaborate with developers to ensure the design is implemented accurately. Your goal is to make financial management as simple and engaging as possible for users.
        
        ##Calculate the {effort} for the design document as follows:

        ##Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        ##Step 2: Set the productivity rate to {80 SLOC completed per day}.
        ##Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure the design is implemented accurately."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="A UI/UX designer in the Scrum team working on the self-budgeting application interface"
)


# Devops Engineer Agent (Process adherence)
devops_engineer_agent = ConversableAgent(
    name="devops_engineer_agent",
    system_message=(
        """You are a DevOps engineer ensuring smooth deployment of the self-budgeting application. Your responsibilities include setting up and maintaining the CI/CD pipeline, managing cloud infrastructure, and implementing monitoring and logging solutions. You work to optimize the development workflow, improve system reliability, and ensure that new features can be deployed quickly and safely.
        ##Calculate the {effort} for the design document as follows:

        ##Step 1: Determine the {work}, which is the estimated number of design pages for the application.
        ##Step 2: Set the productivity rate to {60 SLOC completed per day}.
        ##Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that new features can be deployed quickly and safely"""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="A DevOps engineer ensuring smooth deployment of the self-budgeting application"
)



# Test Engineer Agent (Testing and Validation)
test_engineer_agent = ConversableAgent(
    name="test_engineer",
    system_message=(
        """You are a test engineer in the Scrum team responsible for creating and executing test cases for the budgeting application. Your role involves ensuring all functionalities (income tracking, expense monitoring, notifications, etc.) work as intended.

        Calculate the {effort} to complete testing as follows:

        Step 1: Determine the {work}, which is the estimated number of test cases required.
        Step 2: Set the productivity rate to {2 test cases completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure that the app is stable, secure, and meets user requirements before release."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The agent responsible for testing the budgeting app"
)

# Documentation Engineer Agent (Creating User Documentation)
documentation_engineer_agent = ConversableAgent(
    name="documentation_engineer",
    system_message=(
        """You are a documentation engineer responsible for creating the user manuals and training material for the budgeting app.
        Your role includes writing clear documentation for managing income, expenses, budgets, and reports.

        Calculate the {effort} to create the documentation as follows:

        Step 1: Determine the {work}, which is the estimated number of documentation pages required.
        Step 2: Set the productivity rate to {3 pages completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        Ensure the documentation is user-friendly and comprehensive."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for creating user documentation for the budgeting app"
)
# Out:
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# ...

# %%
from autogen import GroupChat

# %%
group_chat = GroupChat(
    agents=[
        project_manager_agent, # Project Manager monitors throughout
        requirement_engineer_agent,  # Start with requirement gathering
        system_engineer_agent,  # After requirements, move to system design
        software_engineer_agent,  # After system design, start development
        product_owner_agent,
        scrum_master_agent,
        qa_engineer_agent,
        ui_ux_designer_agent,
        devops_engineer_agent,
        test_engineer_agent,  # After development, move to testing
        documentation_engineer_agent,  # After testing, create documentation
        customer_proxy_agent  # Customer Proxy to give final plan and discuss the timeline
    ],
    messages=[],  # Start with an empty message list
    send_introductions=True,  # Introduce each agent at the start
    speaker_selection_method="auto",  # Automatically selects the next speaker in the Waterfall sequence
    max_round=9  # Limit the number of interaction rounds
)

# %%
from autogen import GroupChatManager

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
    llm_config={"config_list": [{"model": "gpt-4o-mini",
                                "api_key": "sk-j7HR-Hx3ZClCrxcJwGiOpfafshi_jNRy9U9nNySFHnT3BlbkFJx5KePtp8U7Uc-UXZB9DK6kL7Wos0fBO97Gc5Y0JKIA"}]},

)
# Out:
# [autogen.oai.client: 10-31 16:50:02] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %%
chat_result = customer_proxy_agent.initiate_chat(
            group_chat_manager,
            message="We need to create a detailed project plan for the development of the Self Budgeting Application. Each member of the team (software_engineer_agent, Requirement Engineer, System Engineer, documentation_engineer_agent) will contribute by defining their part of the plan. We will gather requirements, design the architecture, and estimate the effort required for each phase of the project.",
            summary_method="reflection_with_llm",
        )
# Out:
# customer_proxy (to chat_manager):
#
# We need to create a detailed project plan for the development of the Self Budgeting Application. Each member of the team (software_engineer_agent, Requirement Engineer, System Engineer, documentation_engineer_agent) will contribute by defining their part of the plan. We will gather requirements, design the architecture, and estimate the effort required for each phase of the project.
#
# --------------------------------------------------------------------------------
# [autogen.oai.client: 10-31 16:52:24] {184} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
#
# Next speaker: project_manager
#
# project_manager (to chat_manager):
#
# project_manager: Great! Let's start by determining the total number of tasks required to build the budgeting app. Here’s a breakdown of the core features we need to include:
#
# 1. **Income Tracking**
#    - Define income categories
# ...
