# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Self Budgeting Application</title>
#     <style>
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             background-color: #f0f4f8;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .container {
#             background-color: #ffffff;
#             border-radius: 8px;
#             box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#             padding: 2rem;
#             text-align: center;
#         }
#         h1 {
#             color: #2c3e50;
#             font-size: 2.5rem;
#             margin-bottom: 0.5rem;
#         }
#         h2 {
#             color: #34495e;
#             font-size: 1.8rem;
#             margin-bottom: 1.5rem;
#         }
#         p {
#             color: #3498db;
#             font-size: 1.2rem;
#             font-weight: 500;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>SELF BUDGETING APPLICATION</h1>
#         <h2>Transition from Waterfall to Scrum</h2>
#         <p>Using LangGraph/Langchain</p>
#     </div>
# </body>
# </html>

# %%
pip install langchain langchain-community langgraph openai

# %%
pip install tabulate

# %%
import os
from typing import List
from langchain_community.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema import HumanMessage, SystemMessage

# Set up OpenAI API key
os.environ["OPENAI_API_KEY"] = "sk-j7HR-Hx3ZClCrxcJwGiOpfafshi_jNRy9U9nNySFHnT3BlbkFJx5KePtp8U7Uc-UXZB9DK6kL7Wos0fBO97Gc5Y0JKIA"

llm = ChatOpenAI()

# Define the function to add engineer data
def add_engineer_data(role: str, work: int, productivity_rate: int) -> List:
    effort = work / productivity_rate
    return [role, work, f'{effort:.2f}', productivity_rate]

project_data = []
# Out:
# C:\Users\chait\AppData\Local\Temp\ipykernel_26516\720638315.py:10: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI()

# %%
# Global variable to store project data
project_data = []

def add_engineer_data(role, work, productivity_rate):
    effort = work / productivity_rate
    project_data.append([role, work, f"{effort:.2f}", productivity_rate])

# Define functions for each agent
def customer_proxy_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Customer Proxy, provide an overview of the Self Budgeting Application project requirements."
    )
    response = llm(prompt.format_messages())
    print("Customer Proxy Agent:", response.content)
    # Customer Proxy doesn't have specific tasks, so we don't add it to the project_data

def project_manager_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Project Manager, outline the project plan for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Project Manager Agent:", response.content)
    add_engineer_data("Project Manager Agent", 31, 3)

def requirement_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Requirement Engineer, detail the requirements gathering process for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Requirement Engineer Agent:", response.content)
    add_engineer_data("Requirement Engineer Agent", 20, 4)

def system_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a System Engineer, describe the system architecture for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("System Engineer Agent:", response.content)
    add_engineer_data("System Engineer Agent", 25, 3)

def software_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Software Engineer, outline the development plan for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Software Engineer Agent:", response.content)
    add_engineer_data("Software Engineer Agent", 40, 2)

def ui_ux_designer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a UI/UX Designer, describe the user interface design process for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("UI/UX Designer Agent:", response.content)
    add_engineer_data("UI/UX Designer Agent", 30, 3)

def devops_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a DevOps Engineer, outline the deployment and infrastructure setup for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("DevOps Engineer Agent:", response.content)
    add_engineer_data("DevOps Engineer Agent", 22, 2)

def test_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Test Engineer, describe the testing strategy for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Test Engineer Agent:", response.content)
    add_engineer_data("Test Engineer Agent", 18, 4)

def documentation_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Documentation Engineer, outline the documentation plan for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Documentation Engineer Agent:", response.content)
    add_engineer_data("Documentation Engineer Agent", 12, 3)

def product_owner_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Product Owner, prioritize the features for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("Product Owner Agent:", response.content)
    add_engineer_data("Product Owner Agent", 15, 5)

def scrum_master_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a Scrum Master, describe how you will facilitate the Scrum process for the Self Budgeting Application project."
    )
    response = llm(prompt.format_messages())
    print("Scrum Master Agent:", response.content)
    add_engineer_data("Scrum Master Agent", 18, 4)

def qa_engineer_agent():
    prompt = ChatPromptTemplate.from_template(
        "As a QA Engineer, outline the quality assurance process for the Self Budgeting Application."
    )
    response = llm(prompt.format_messages())
    print("QA Engineer Agent:", response.content)
    add_engineer_data("QA Engineer Agent", 22, 3)

# %%
# Run the group chat
customer_proxy_agent()
project_manager_agent()
requirement_engineer_agent()
system_engineer_agent()
software_engineer_agent()
ui_ux_designer_agent()
devops_engineer_agent()
test_engineer_agent()
documentation_engineer_agent()
product_owner_agent()
scrum_master_agent()
qa_engineer_agent()
# Out:
# C:\Users\chait\AppData\Local\Temp\ipykernel_26516\3812822835.py:13: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(prompt.format_messages())
# Customer Proxy Agent: The Self Budgeting Application project aims to create a user-friendly and efficient tool for individuals to manage their finances effectively. The main requirements for this project include:
#
# 1. User Registration and Login: Users should be able to create an account and log in securely to access the application.
#
# 2. Budgeting Tools: Users should be able to set up budgets for different categories such as groceries, entertainment, bills, etc. They should also be able to track their expenses and income in real-time.
#
# ...

# %%
from tabulate import tabulate

# Print the table after all output is produced
headers = ["Agent", "Work (tasks)", "Effort (days)", "Productivity Rate (tasks/day)"]
table = tabulate(project_data, headers=headers, tablefmt="grid")
print(table)
# Out:
# +------------------------------+----------------+-----------------+---------------------------------+
# | Agent                        |   Work (tasks) |   Effort (days) |   Productivity Rate (tasks/day) |
# +==============================+================+=================+=================================+
# | Project Manager Agent        |             31 |           10.33 |                               3 |
# +------------------------------+----------------+-----------------+---------------------------------+
# | Requirement Engineer Agent   |             20 |            5    |                               4 |
# +------------------------------+----------------+-----------------+---------------------------------+
# | System Engineer Agent        |             25 |            8.33 |                               3 |
# +------------------------------+----------------+-----------------+---------------------------------+
# ...
